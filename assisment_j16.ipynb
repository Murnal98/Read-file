# %% [markdown]
# <a href="https://colab.research.google.com/github/Murnal98/Read-file/blob/main/assisment_j16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the library
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pm = pd.read_csv("/content/monster_com-job_sample.csv.zip")

# %%
#ckeck size our dataset
pm.size
# Out:
# 308000

# %%
#check shape how many colomn and row in our dataset
pm.shape
# Out:
# (22000, 14)

# %%
#started row and colomn according to our requrment
pm.head(3)
# Out:
#                     country country_code date_added has_expired  \
# 0  United States of America           US        NaN          No
# 1  United States of America           US        NaN          No
# 2  United States of America           US        NaN          No
#
#           job_board                                    job_description  \
# 0  jobs.monster.com  TeamSoft is seeing an IT Support Specialist to...
# 1  jobs.monster.com  The Wisconsin State Journal is seeking a flexi...
# 2  jobs.monster.com  Report this job About the Job DePuy Synthes Co...
#
#                                            job_title             job_type  \
# 0               IT Support Technician Job in Madison   Full Time Employee
# 1            Business Reporter/Editor Job in Madison            Full Time
# 2  Johnson & Johnson Family of Companies Job Appl...  Full Time, Employee
#
#                                             location  \
# 0                                  Madison, WI 53702
# ...

# %%
#last default five row and colomn
pm.tail()
# Out:
#                         country country_code date_added has_expired  \
# 21995  United States of America           US        NaN          No
# 21996  United States of America           US        NaN          No
# 21997  United States of America           US        NaN          No
# 21998  United States of America           US        NaN          No
# 21999  United States of America           US        NaN          No
#
#               job_board                                    job_description  \
# 21995  jobs.monster.com  This is a major premier Cincinnati based finan...
# 21996  jobs.monster.com  Luxury homebuilder in Cincinnati seeking multi...
# 21997  jobs.monster.com  RE: Adobe AEM-          Client -          Loca...
# 21998  jobs.monster.com  Jernberg Industries was established in 1937 an...
# 21999  jobs.monster.com  Contract AdministratorCan you be the point per...
#
#                                                job_title            job_type  \
# ...

# %%
#all information about our dataset
pm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          22000 non-null  object
#  1   country_code     22000 non-null  object
#  2   date_added       122 non-null    object
#  3   has_expired      22000 non-null  object
#  4   job_board        22000 non-null  object
#  5   job_description  22000 non-null  object
#  6   job_title        22000 non-null  object
#  7   job_type         20372 non-null  object
#  8   location         22000 non-null  object
#  9   organization     15133 non-null  object
#  10  page_url         22000 non-null  object
#  11  salary           3446 non-null   object
#  12  sector           16806 non-null  object
#  13  uniq_id          22000 non-null  object
# dtypes: object(14)
# memory usage: 2.3+ MB

# %%
#how many colomn in our dataset
pm.columns
# Out:
# Index(['country', 'country_code', 'date_added', 'has_expired', 'job_board',
#        'job_description', 'job_title', 'job_type', 'location', 'organization',
#        'page_url', 'salary', 'sector', 'uniq_id'],
#       dtype='object')

# %%
#salary colomn details
pm['salary']
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 21995                 120,000.00 - 160,000.00 $ /yearbonus
# 21996                        45,000.00 - 60,000.00 $ /year
# 21997                                                  NaN
# 21998                                25.00 - 28.00 $ /hour
# 21999    40,000.00 - 46,000.00 $ /year+ annual bonus (u...
# Name: salary, Length: 22000, dtype: object

# %%
#statical representation of our data
pm.describe()
# Out:
#                          country country_code date_added has_expired  \
# count                      22000        22000        122       22000
# unique                         1            1         78           1
# top     United States of America           US  9/22/2016          No
# freq                       22000        22000          6       22000
#
#                job_board                                    job_description  \
# count              22000                                              22000
# unique                 1                                              18744
# top     jobs.monster.com  12N Horizontal Construction Engineers Job Desc...
# freq               22000                                                104
#
#        job_title   job_type    location         organization  \
# count      22000      20372       22000                15133
# unique     18759         39        8423                  738
# ...

# %%
#use isna we show our values true and false form
pm.isna()
# Out:
#        country  country_code  date_added  has_expired  job_board  \
# 0        False         False        True        False      False
# 1        False         False        True        False      False
# 2        False         False        True        False      False
# 3        False         False        True        False      False
# 4        False         False        True        False      False
# ...        ...           ...         ...          ...        ...
# 21995    False         False        True        False      False
# 21996    False         False        True        False      False
# 21997    False         False        True        False      False
# 21998    False         False        True        False      False
# 21999    False         False        True        False      False
#
#        job_description  job_title  job_type  location  organization  page_url  \
# 0                False      False     False     False          True     False
# ...

# %%
#we check null values in our dataset
pm.isna().sum()
# Out:
# country                0
# country_code           0
# date_added         21878
# has_expired            0
# job_board              0
# job_description        0
# job_title              0
# job_type            1628
# location               0
# organization        6867
# page_url               0
# salary             18554
# sector              5194
# uniq_id                0
# dtype: int64

# %%
#we check null values orderd vise
pm.isna().sum().sort_values()
# Out:
# country                0
# country_code           0
# has_expired            0
# job_board              0
# job_description        0
# job_title              0
# location               0
# page_url               0
# uniq_id                0
# job_type            1628
# sector              5194
# organization        6867
# salary             18554
# date_added         21878
# dtype: int64

# %%
#check all the null values percentage
#how many percent null value giving the space in our dataset
pm.isna().sum().sort_values()/len(pm.index)*100
# Out:
# country             0.000000
# country_code        0.000000
# has_expired         0.000000
# job_board           0.000000
# job_description     0.000000
# job_title           0.000000
# location            0.000000
# page_url            0.000000
# uniq_id             0.000000
# job_type            7.400000
# sector             23.609091
# organization       31.213636
# salary             84.336364
# date_added         99.445455
# dtype: float64

# %%
#visulization of null values by heatmap
#all white line showing null values in our dataset
plt.figure(figsize=(16,9))
sns.heatmap(pm.isnull(), cbar=False)

# %%
#we are replacing all the null values in our dataset using this code
pra1=pm.replace(np.nan,'',regex= True)
pra1
# Out:
#                         country country_code date_added has_expired  \
# 0      United States of America           US                     No
# 1      United States of America           US                     No
# 2      United States of America           US                     No
# 3      United States of America           US                     No
# 4      United States of America           US                     No
# ...                         ...          ...        ...         ...
# 21995  United States of America           US                     No
# 21996  United States of America           US                     No
# 21997  United States of America           US                     No
# 21998  United States of America           US                     No
# 21999  United States of America           US                     No
#
#               job_board                                    job_description  \
# ...

# %%
#we remove all the spacial charecter from choosing perticuler colomn
spec_chars = ["!",'"',"#","%","&","'","(",")",
              "*","+",",","-",".","/",":",";","<",
              "=",">","?","@","[","\\","]","^","_",
              "`","{","|","}","~","–"]

for char in spec_chars:
    pm['salary'] = pm['salary'].str.replace(char, ' ')
    pm['job_description'] = pm['job_description'].str.replace(char, ' ')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   if __name__ == '__main__':

# %%
#we check in the salary colomn all spacial charecter
pm['salary'].unique()
# Out:
# array([nan, '9 00   13 00 $  hour', '80 000 00   95 000 00 $  year', ...,
#        '$80 000 00   year', '120 000 00   160 000 00 $  yearbonus',
#        '40 000 00   46 000 00 $  year  annual bonus  up to 15  of salary '],
#       dtype=object)

# %%
#drop useless colomn
pm.drop(['date_added','page_url','uniq_id'], axis = 1)
# Out:
#                         country country_code has_expired         job_board  \
# 0      United States of America           US          No  jobs.monster.com
# 1      United States of America           US          No  jobs.monster.com
# 2      United States of America           US          No  jobs.monster.com
# 3      United States of America           US          No  jobs.monster.com
# 4      United States of America           US          No  jobs.monster.com
# ...                         ...          ...         ...               ...
# 21995  United States of America           US          No  jobs.monster.com
# 21996  United States of America           US          No  jobs.monster.com
# 21997  United States of America           US          No  jobs.monster.com
# 21998  United States of America           US          No  jobs.monster.com
# 21999  United States of America           US          No  jobs.monster.com
#
#                                          job_description  \
# ...

# %%
#check type of the dataset
pm.dtypes
# Out:
# country            object
# country_code       object
# date_added         object
# has_expired        object
# job_board          object
# job_description    object
# job_title          object
# job_type           object
# location           object
# organization       object
# page_url           object
# salary             object
# sector             object
# uniq_id            object
# dtype: object

# %%
#from the salary colomn remove spacial values
pm['salary'] = pm['salary'].replace({'\$': '', ',': ''}, regex=True)
pm
# Out:
#                         country country_code date_added has_expired  \
# 0      United States of America           US        NaN          No
# 1      United States of America           US        NaN          No
# 2      United States of America           US        NaN          No
# 3      United States of America           US        NaN          No
# 4      United States of America           US        NaN          No
# ...                         ...          ...        ...         ...
# 21995  United States of America           US        NaN          No
# 21996  United States of America           US        NaN          No
# 21997  United States of America           US        NaN          No
# 21998  United States of America           US        NaN          No
# 21999  United States of America           US        NaN          No
#
#               job_board                                    job_description  \
# ...

# %%
#drop all this colomn because more than 30% null values colomn efected of accurecy
pm.drop(['job_type','job_description','country','country_code','job_board','has_expired','date_added','page_url','uniq_id','salary'], axis = 1,inplace = True)

# %%
#convert calegorical values in integer 
pm = pd.DataFrame({col:pm[col].astype('category').cat.codes for col in pm},index = pm.index)
pm
# Out:
#        job_title  location  organization  sector
# 0           7860      4653            -1     102
# 1           2246      4658           538      -1
# 2           8337      2347           531      -1
# 3           5421      2525           101      56
# 4          16354      1271           580     137
# ...          ...       ...           ...     ...
# 21995       1298      1561            -1      -1
# 21996        391      1589           264     111
# 21997        158      1508            -1      -1
# 21998       5351      1514           419     103
# 21999       3519      1561            -1      56
#
# [22000 rows x 4 columns]

# %%
#again we use heatmap for checking null value ,now this time on any null values in our dataset
plt.figure(figsize=(16,9))
sns.heatmap(pm.isnull(), cbar=False)

# %%
#checking categirical data
sector = [pm['sector'].values]
sns.distplot(sector)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
 organization= [pm['organization'].values]
sns.distplot(organization)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# heat map of correlation of features
correlation_matrix = pm.corr()
fig = plt.figure(figsize=(12,9))
sns.heatmap(correlation_matrix,vmax=0.8,square = True)
plt.show()

# %%
pm['Vamount'] = StandardScaler().fit_transform(pm['job_title'].values.reshape(-1,1))
pm['Vtime'] = StandardScaler().fit_transform(pm['location'].values.reshape(-1,1))
pm.head()
# Out:
#    job_title  location  organization  sector   Vamount     Vtime
# 0       7860      4653            -1     102 -0.314247  0.357005
# 1       2246      4658           538      -1 -1.354473  0.359158
# 2       8337      2347           531      -1 -0.225863 -0.635701
# 3       5421      2525           101      56 -0.766173 -0.559074
# 4      16354      1271           580     137  1.259618 -1.098906

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x.values)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['job_title','location'])
finalDf = pd.concat([principalDf, y], axis = 1)
finalDf.head()
# Out:
#      job_title     location  organization  sector
# 0  1684.735812   851.875910            -1     102
# 1  7298.168510   931.840565           538      -1
# 2  1238.570917 -1460.287987           531      -1
# 3  4151.934054 -1243.365803           101      56
# 4 -6763.346211 -2643.244994           580     137

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('organization', fontsize = 15)
ax.set_ylabel('sector', fontsize = 15)
ax.set_title('jaishree Malode', fontsize = 20)
targets = [0, 1]
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = pm['sector'] == target
    ax.scatter(pm.loc[indicesToKeep,'organization' ]
               , pm.loc[indicesToKeep,'sector']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
x = pm[['job_title','location']]
x
# Out:
#        job_title  location
# 0           7860      4653
# 1           2246      4658
# 2           8337      2347
# 3           5421      2525
# 4          16354      1271
# ...          ...       ...
# 21995       1298      1561
# 21996        391      1589
# 21997        158      1508
# 21998       5351      1514
# 21999       3519      1561
#
# [22000 rows x 2 columns]

# %%
y = pm[['organization','sector']]
y
# Out:
#        organization  sector
# 0                -1     102
# 1               538      -1
# 2               531      -1
# 3               101      56
# 4               580     137
# ...             ...     ...
# 21995            -1      -1
# 21996           264     111
# 21997            -1      -1
# 21998           419     103
# 21999            -1      56
#
# [22000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split               
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
len(x_train)
# Out:
# 17600

# %%
len(y_test)
# Out:
# 4400

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
regressor.predict(x_test)
# Out:
# array([[242.98123789,  62.67400589],
#        [248.48930065,  63.48785882],
#        [242.12262716,  64.39152083],
#        ...,
#        [238.44990531,  57.351874  ],
#        [239.94989241,  61.17491665],
#        [249.43933342,  62.92293844]])

# %%
regressor.predict(y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - organization
# - sector
# Feature names seen at fit time, yet now missing:
# - job_title
# - location
#
#   warnings.warn(message, FutureWarning)
# array([[240.56716508,  54.0298226 ],
#        [240.24201716,  53.73858393],
#        [240.54962057,  54.0156155 ],
#        ...,
#        [240.04561983,  53.75138993],
#        [240.39997617,  53.96848366],
#        [240.75189848,  54.17941507]])

# %%
regressor.score(x_test,y_test)
# Out:
# 0.006890206054683545

# %%
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'green')
plt.title('salary vs yearExp (Training set)')
plt.xlabel('years of experience')
plt.ylabel('salary')
plt.show()

# %%
print(x_test)
# Out:
#        job_title  location
# 2961       10092      4844
# 17933      11391      2234
# 11500      11932      6571
# 8943        7555      1550
# 6692        4190      2052
# ...          ...       ...
# 21405        615      4972
# 21977      11069      1564
# 2915        3871      3661
# 5258        8213      5528
# 20828      10834      1279
#
# [4400 rows x 2 columns]

# %%
print(y_test)
# Out:
#        organization  sector
# 2961            345      56
# 17933            -1      36
# 11500           328      56
# 8943             53      -1
# 6692            246      -1
# ...             ...     ...
# 21405           440      10
# 21977            74      56
# 2915             -1     159
# 5258            265     109
# 20828           524      56
#
# [4400 rows x 2 columns]
