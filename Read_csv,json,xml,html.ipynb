# %% [markdown]
# ## **csv** **read**

# %%
import pandas as pd
import numpy as np
jm = pd.read_csv("/content/Filpkart.csv/content/Filpkart.csv")
jm
# Out:
#                                Uniq Id  ...                                                Url
# 0     0633d9fd9a3271730fae687f105c7a3a  ...  https://www.flipkart.com/b-natural-dakshin-pin...
# 1     8687c5317c6629f89fe62e0233563246  ...  https://www.flipkart.com/parle-melody-chocolat...
# 2     cf7eeba428641c14e43aa18ada1b5491  ...  https://www.flipkart.com/whiskas-adult-1-year-...
# 3     9eb4d8359a3cbe7af6c5ac1c3149940e  ...  https://www.flipkart.com/enchanteur-romantic-p...
# 4     b84c9f6fc53da0c6921147063d894703  ...  https://www.flipkart.com/pantene-hair-fall-con...
# ...                                ...  ...                                                ...
# 5545  51fba5b6032f5f8b943d9be25a42d85b  ...  https://www.flipkart.com/jivo-pure-olive-oil-g...
# 5546  b38faef6bbf30ff487df297fbe33935c  ...  https://www.flipkart.com/lizol-disinfectant-su...
# 5547  e3f6176b1d64faa32c4fe0bdea42150c  ...  https://www.flipkart.com/excel-plus-floor-clea...
# ...

# %%
print(jm.isnull().sum())
jm
# Out:
# Uniq Id                     0
# Crawl Timestamp             0
# Bb Category                 0
# Product Title               0
# Product Description      4590
# Brand                       0
# Quantity Or Pack Size      33
# Mrp                         0
# Price                       0
# Site Name                   0
# Offers                     63
# Combo Offers             5315
# Stock Availibility          1
# Image Url                   2
# Url                         1
# dtype: int64
#                                Uniq Id  ...                                                Url
# 0     0633d9fd9a3271730fae687f105c7a3a  ...  https://www.flipkart.com/b-natural-dakshin-pin...
# 1     8687c5317c6629f89fe62e0233563246  ...  https://www.flipkart.com/parle-melody-chocolat...
# 2     cf7eeba428641c14e43aa18ada1b5491  ...  https://www.flipkart.com/whiskas-adult-1-year-...
# 3     9eb4d8359a3cbe7af6c5ac1c3149940e  ...  https://www.flipkart.com/enchanteur-romantic-p...
# ...

# %% [markdown]
# # **HTML** **Read**

# %%
jm = pd.read_html("https://en.wikipedia.org/wiki/Education")
jm
# Out:
# [    0                                                  1
#  0 NaN  This article needs additional citations for ve...,
#      0                                                  1
#  0 NaN  This article needs additional citations for ve...,
#      0                                                  1
#  0 NaN  This section needs additional citations for ve...,
#      0                                                  1
#  0 NaN  The examples and perspective in this section d...,
#                                     0
#  0  Library resources about Education
#  1          Resources in your library,
# ...

# %%
jm = pd.DataFrame(output)
jm
# Out:
#            statename state_id  ... totalnoof_medium              createddate
# 0  JAMMU AND KASHMIR        1  ...               11  2022-02-16T08:08:18.333
# 1  JAMMU AND KASHMIR        1  ...                2  2022-02-16T08:08:18.333
# 2  JAMMU AND KASHMIR        1  ...                0  2022-02-16T08:08:18.333
# 3  JAMMU AND KASHMIR        1  ...                3  2022-02-16T08:08:18.333
# 4  JAMMU AND KASHMIR        1  ...                1  2022-02-16T08:08:18.333
# 5  JAMMU AND KASHMIR        1  ...                2  2022-02-16T08:08:18.333
# 6  JAMMU AND KASHMIR        1  ...               39  2022-02-16T08:08:18.333
# 7  JAMMU AND KASHMIR        1  ...                1  2022-02-16T08:08:18.333
# 8  JAMMU AND KASHMIR        1  ...               15  2022-02-16T08:08:18.333
# 9  JAMMU AND KASHMIR        1  ...                1  2022-02-16T08:08:18.333
#
# [10 rows x 9 columns]

# %%
jm.replace(np.nan,'')
# Out:
#                                Uniq Id  ...                                                Url
# 0     0633d9fd9a3271730fae687f105c7a3a  ...  https://www.flipkart.com/b-natural-dakshin-pin...
# 1     8687c5317c6629f89fe62e0233563246  ...  https://www.flipkart.com/parle-melody-chocolat...
# 2     cf7eeba428641c14e43aa18ada1b5491  ...  https://www.flipkart.com/whiskas-adult-1-year-...
# 3     9eb4d8359a3cbe7af6c5ac1c3149940e  ...  https://www.flipkart.com/enchanteur-romantic-p...
# 4     b84c9f6fc53da0c6921147063d894703  ...  https://www.flipkart.com/pantene-hair-fall-con...
# ...                                ...  ...                                                ...
# 5545  51fba5b6032f5f8b943d9be25a42d85b  ...  https://www.flipkart.com/jivo-pure-olive-oil-g...
# 5546  b38faef6bbf30ff487df297fbe33935c  ...  https://www.flipkart.com/lizol-disinfectant-su...
# 5547  e3f6176b1d64faa32c4fe0bdea42150c  ...  https://www.flipkart.com/excel-plus-floor-clea...
# ...

# %% [markdown]
# # **XML** **read**

# %%
jm = pd.read_xml("https://api.data.gov.in/resource/201b66f2-7fda-40b8-b613-ffb7789c4341?api-key=579b464db66ec23bdd000001cdd3946e44ce4aad7209ff7b23ac571b&format=xml&offset=0&limit=10")
jm
# Out:
#                               index_name  ... offset
# 0   201b66f2-7fda-40b8-b613-ffb7789c4341  ...    NaN
# 1                                   None  ...    NaN
# 2                                   None  ...    NaN
# 3                                   None  ...    NaN
# 4                                   None  ...    NaN
# 5                                   None  ...    NaN
# 6                                   None  ...    NaN
# 7                                   None  ...    NaN
# 8                                   None  ...    NaN
# 9                                   None  ...    NaN
# 10                                  None  ...    NaN
# 11                                  None  ...    NaN
# 12                                  None  ...    NaN
# 13                                  None  ...    NaN
# 14                                  None  ...    NaN
# 15                                  None  ...    NaN
# 16                                  None  ...    NaN
# ...

# %% [markdown]
# # **JSON** **Read**

# %%
import requests
jm = requests.get("https://api.data.gov.in/resource/47d1657d-4183-46ed-bfc2-0b9a5694a742?api-key=579b464db66ec23bdd000001cdd3946e44ce4aad7209ff7b23ac571b&format=json&offset=0&limit=10")
print(jm.status_code)
data = jm.json()
output=data['records']
# Out:
# 200

# %%
output
# Out:
# [{'createddate': '2022-02-16T08:08:18.333',
#   'district_id': '36',
#   'districtname': 'ANANTNAG',
#   'state_id': '1',
#   'statename': 'JAMMU AND KASHMIR',
#   'totalnoof_medium': '11',
#   'totalnoof_micro': '277',
#   'totalnoof_small': '85',
#   'totalnoofapplication': '373'},
#  {'createddate': '2022-02-16T08:08:18.333',
#   'district_id': '34',
#   'districtname': 'BADGAM',
#   'state_id': '1',
#   'statename': 'JAMMU AND KASHMIR',
#   'totalnoof_medium': '2',
#   'totalnoof_micro': '791',
#   'totalnoof_small': '116',
#   'totalnoofapplication': '909'},
#  {'createddate': '2022-02-16T08:08:18.333',
#   'district_id': '604',
#   'districtname': 'BANDIPORA',
#   'state_id': '1',
#   'statename': 'JAMMU AND KASHMIR',
#   'totalnoof_medium': '0',
#   'totalnoof_micro': '59',
#   'totalnoof_small': '43',
#   'totalnoofapplication': '102'},
#  {'createddate': '2022-02-16T08:08:18.333',
#   'district_id': '32',
#   'districtname': 'BARAMULLA',
#   'state_id': '1',
# ...

# %%
pm =pd.DataFrame(output)
pm
# Out:
#            statename state_id  ... totalnoof_medium              createddate
# 0  JAMMU AND KASHMIR        1  ...               11  2022-02-16T08:08:18.333
# 1  JAMMU AND KASHMIR        1  ...                2  2022-02-16T08:08:18.333
# 2  JAMMU AND KASHMIR        1  ...                0  2022-02-16T08:08:18.333
# 3  JAMMU AND KASHMIR        1  ...                3  2022-02-16T08:08:18.333
# 4  JAMMU AND KASHMIR        1  ...                1  2022-02-16T08:08:18.333
# 5  JAMMU AND KASHMIR        1  ...                2  2022-02-16T08:08:18.333
# 6  JAMMU AND KASHMIR        1  ...               39  2022-02-16T08:08:18.333
# 7  JAMMU AND KASHMIR        1  ...                1  2022-02-16T08:08:18.333
# 8  JAMMU AND KASHMIR        1  ...               15  2022-02-16T08:08:18.333
# 9  JAMMU AND KASHMIR        1  ...                1  2022-02-16T08:08:18.333
#
# [10 rows x 9 columns]

# %% [markdown]
# # **JPG** **Image**

# %%
from PIL import Image
jpeg = Image.open("/content/nural.jpg")
print(jpeg.format, jpeg.size, jpeg.mode)
# Out:
# JPEG (278, 181) RGB

# %%
jpeg
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=278x181 at 0x7FDD477A8E50>

# %% [markdown]
# # **PNG** **Image**

# %%
from PIL import Image
png = Image.open("/content/google.png")
png
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x405 at 0x7FDD477B2410>

# %% [markdown]
# # **PDF** **Read**

# %%
pip install tabula-py
# Out:
# ...
#      |████████████████████████████████| 12.0 MB 22.3 MB/s
# ...

# %%
# !java verson
# Out:
# Error: Could not find or load main class verson
# Caused by: java.lang.ClassNotFoundException: verson

# %%
from tabula import read_pdf
jm = read_pdf("/content/drive/MyDrive/architects1 (2).pdf")
jm[0]
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
# Got stderr: Feb 16, 2022 4:13:56 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# Feb 16, 2022 4:13:56 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# Feb 16, 2022 4:13:56 AM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
#    S.No  ...                                    Contact Details
# 0   1.0  ...  Tel: 95120-5321278\r9818290708\rEmail: info@st...
# 1   2.0  ...      Tel: 033-24740570-73\rEmail: jpamnl@gmail.com
# 2   3.0  ...  Tel: 27457241\r23857061, 23857824\rFax: 238590...
# 3   4.0  ...  Tel: 24682100/ 41504900 extn.2139\r\rEmail: mi...
# 4   5.0  ...             Tel: 95124-4065318\rFax: 95124-2352829
# ...

# %%
df = pd.DataFrame(output)
df
# Out:
#            statename state_id  ... totalnoof_medium              createddate
# 0  JAMMU AND KASHMIR        1  ...               11  2022-02-16T08:08:18.333
# 1  JAMMU AND KASHMIR        1  ...                2  2022-02-16T08:08:18.333
# 2  JAMMU AND KASHMIR        1  ...                0  2022-02-16T08:08:18.333
# 3  JAMMU AND KASHMIR        1  ...                3  2022-02-16T08:08:18.333
# 4  JAMMU AND KASHMIR        1  ...                1  2022-02-16T08:08:18.333
# 5  JAMMU AND KASHMIR        1  ...                2  2022-02-16T08:08:18.333
# 6  JAMMU AND KASHMIR        1  ...               39  2022-02-16T08:08:18.333
# 7  JAMMU AND KASHMIR        1  ...                1  2022-02-16T08:08:18.333
# 8  JAMMU AND KASHMIR        1  ...               15  2022-02-16T08:08:18.333
# 9  JAMMU AND KASHMIR        1  ...                1  2022-02-16T08:08:18.333
#
# [10 rows x 9 columns]
